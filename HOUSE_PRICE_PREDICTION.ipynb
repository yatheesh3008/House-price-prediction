# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/1553768847-housing.csv (1).zip')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   ocean_proximity     20433 non-null  object
#  9   median_house_value  20433 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data= X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19056    -121.74     38.15                  22         1910           326.0
# 12991    -121.25     38.70                  16         3262           533.0
# 3915     -118.52     34.19                  37         1560           275.0
# 11352    -117.92     33.75                  23          893           223.0
# 9504     -123.36     39.01                  35         1551           321.0
# ...          ...       ...                 ...          ...             ...
# 1913     -120.06     39.01                  19         2967           528.0
# 12398    -116.31     33.67                  15         2214           410.0
# 10753    -117.89     33.61                  44         2126           423.0
# 12785    -121.44     38.63                  38         1673           399.0
# 9111     -118.15     34.59                  33         2111           429.0
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <ipython-input-18-89e36abfcc5f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     7230
# INLAND        5178
# NEAR OCEAN    2104
# NEAR BAY      1829
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19056    -121.74     38.15                  22     7.555382        5.789960
# 12991    -121.25     38.70                  16     8.090402        6.280396
# 3915     -118.52     34.19                  37     7.353082        5.620401
# 11352    -117.92     33.75                  23     6.795706        5.411646
# 9504     -123.36     39.01                  35     7.347300        5.774552
# ...          ...       ...                 ...          ...             ...
# 1913     -120.06     39.01                  19     7.995644        6.270988
# 12398    -116.31     33.67                  15     7.703008        6.018593
# 10753    -117.89     33.61                  44     7.662468        6.049733
# 12785    -121.44     38.63                  38     7.422971        5.991465
# 9111     -118.15     34.59                  33     7.655391        6.063785
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
X = train_data.drop(['median_house_value'], axis=1)
y = train_data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19056    -121.74     38.15                  22     7.555382        5.789960
# 12991    -121.25     38.70                  16     8.090402        6.280396
# 3915     -118.52     34.19                  37     7.353082        5.620401
# 11352    -117.92     33.75                  23     6.795706        5.411646
# 9504     -123.36     39.01                  35     7.347300        5.774552
# ...          ...       ...                 ...          ...             ...
# 1913     -120.06     39.01                  19     7.995644        6.270988
# 12398    -116.31     33.67                  15     7.703008        6.018593
# 10753    -117.89     33.61                  44     7.662468        6.049733
# 12785    -121.44     38.63                  38     7.422971        5.991465
# 9111     -118.15     34.59                  33     7.655391        6.063785
#
# ...

# %%
y
# Out:
# 19056    115800
# 12991    144400
# 3915     206900
# 11352    156300
# 9504     115400
#           ...
# 1913     437500
# 12398     93400
# 10753    500001
# 12785     62200
# 9111     111400
# Name: median_house_value, Length: 16346, dtype: int64

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

class LinearRegression:
    def __init__(self, learning_rate=0.1, max_iterations=1000, alpha=0.01, gradient_type="batch"):
        self.learning_rate = learning_rate
        self.max_iterations = max_iterations
        self.alpha = alpha
        self.gradient_type = gradient_type

    def fit(self, X, y):
        # Add a column of ones for the intercept term
        X = np.insert(X, 0, 1, axis=1)

        # Initialize the weights
        self.weights = np.zeros(X.shape[1])

        # Define the gradient function
        def gradient(X, y, weights):
            y_pred = np.dot(X, weights)
            errors = y_pred - y
            grad = np.dot(X.T, errors) / len(y)
            return grad

        # Define the stochastic gradient function
        def stochastic_gradient(X, y, weights):
            i = np.random.randint(len(y))
            xi = X[i]
            yi = y[i]
            y_pred = np.dot(xi, weights)
            error = y_pred - yi
            grad = xi * error
            return grad

        # Define the mini-batch gradient function
        def minibatch_gradient(X, y, weights, batch_size=20):
            batch_indices = np.random.choice(len(y), batch_size, replace=False)
            X_batch = X[batch_indices]
            y_batch = y[batch_indices]
            y_pred = np.dot(X_batch, weights)
            errors = y_pred - y_batch
            grad = np.dot(X_batch.T, errors) / len(y_batch)
            return grad

        # Select the appropriate gradient function
        if self.gradient_type == "batch":
            grad_func = gradient
        elif self.gradient_type == "stochastic":
            grad_func = stochastic_gradient
        elif self.gradient_type == "mini-batch":
            grad_func = minibatch_gradient

        # Perform gradient descent
        for i in range(self.max_iterations):
            grad = grad_func(X, y, self.weights)
            self.weights -= self.learning_rate * (grad + self.alpha * self.weights)

    def predict(self, X):
        # Add a column of ones for the intercept term
        X = np.insert(X, 0, 1, axis=1)
        y_pred = np.dot(X, self.weights)
        return y_pred

# %%
y_pred
# Out:
# Ellipsis

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

lr = LinearRegression(learning_rate=0.1, max_iterations=1000, alpha=0.01, gradient_type="batch")
lr.fit(X_scaled, y)

# Make predictions on new X values
X_new = np.array([[-118.13,	33.78,	31,	8.019613,	6.606650,	7.090077,	6.548219,	3.7232,0,0,0,0,1]])
X_new_scaled = scaler.transform(X_new)
y_pred = lr.predict(X_new_scaled)

print(y_pred)
# Out:
# [272954.07846732]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
